# %%
## import modules
import pandas as pd
import numpy as np
import seaborn as sns
import palettable
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.stattools import adfuller
import statsmodels.api as sm

from sklearn.decomposition import PCA

# %% [markdown]
# ## Align Data

# %%
## read the data 
datafile = "../data/"
var_lists = ["real_interest_rate","capacity_util","CPI","stickyCPI","PCE", "fed_fund_rate","unemploy_rate",
    "employ_level_nonagri", "employ_level", "housing_started","housing_completed","GDP","personal_saving_rate",
            "avg_house_prices","mortgage"]

homeprice_index = pd.read_csv(datafile +"national_home_price_index.csv")
homeprice_index.rename(columns = {"value":"national_home_price_index"}, inplace = True)
aligned_data = homeprice_index.copy()
homeprice_index
# Out:
#            date  national_home_price_index
# 0    1987-01-01                     63.735
# 1    1987-02-01                     64.135
# 2    1987-03-01                     64.470
# 3    1987-04-01                     64.973
# 4    1987-05-01                     65.547
# ..          ...                        ...
# 434  2023-03-01                    297.318
# 435  2023-04-01                    301.462
# 436  2023-05-01                    305.421
# 437  2023-06-01                    308.316
# 438  2023-07-01                    310.158
#
# [439 rows x 2 columns]

# %%
## append more date before 
date_app = pd.DataFrame(["1986-{:02d}-01".format(i) for i in range(1,13)], columns = ["date"])
aligned_data = pd.concat([date_app,aligned_data], axis =0)

# %%
## align the data
for val in var_lists:
    value = pd.read_csv(datafile + val +".csv")
    value.rename(columns = {"value":val}, inplace = True)
    ## adjust for the GDP look-ahead problem - delay by one quarter 
    if val == "GDP":
        value = pd.concat([value,pd.DataFrame([{"date":"2023-07-01", "GDP": np.nan}])], axis = 0)
        value["GDP_incre_lastQuarter"] = np.log(value["GDP"]).diff().shift(1)
        aligned_data = pd.merge(aligned_data, value, how = "left", on = ["date"])
        aligned_data["GDP_incre_lastQuarter"] = aligned_data["GDP_incre_lastQuarter"].ffill()
    else:
        aligned_data = pd.merge(aligned_data, value, how = "left", on = ["date"])
aligned_data["date"] = aligned_data["date"].apply(lambda x: pd.to_datetime(x))
aligned_data
# Out:
#           date  national_home_price_index  real_interest_rate  capacity_util  \
# 0   1986-01-01                        NaN            4.547185        79.5636
# 1   1986-02-01                        NaN            4.623880        78.9134
# 2   1986-03-01                        NaN            4.209182        78.2664
# 3   1986-04-01                        NaN            3.948305        78.2696
# 4   1986-05-01                        NaN            4.046590        78.3421
# ..         ...                        ...                 ...            ...
# 446 2023-03-01                    297.318            2.059636        79.5118
# 447 2023-04-01                    301.462            1.443914        79.7900
# 448 2023-05-01                    305.421            1.536904        79.4570
# 449 2023-06-01                    308.316            1.060631        78.9301
# 450 2023-07-01                    310.158            1.426047        79.6066
#
#          CPI  stickyCPI      PCE  fed_fund_rate  unemploy_rate  \
# 0    109.900   0.487140   2827.1           8.14            6.7
# 1    109.700   0.363870   2820.2           7.86            7.2
# 2    109.100   0.488280   2823.6           7.48            7.2
# 3    108.700   0.448070   2835.2           6.99            7.1
# 4    109.000   0.262490   2857.5           6.85            7.2
# ..       ...        ...      ...            ...            ...
# 446  301.808   0.383314  18282.6           4.65            3.5
# 447  302.918   0.382397  18363.8           4.83            3.4
# 448  303.294   0.336291  18407.8           5.06            3.7
# 449  303.841   0.241034  18485.4           5.08            3.6
# 450  304.348   0.256887  18643.3           5.12            3.5
#
#      employ_level_nonagri  employ_level  housing_started  housing_completed  \
# 0                  105600        108887           1972.0             1723.0
# 1                  105397        108480           1848.0             1753.0
# 2                  105637        108837           1876.0             1756.0
# 3                  105799        108952           1933.0             1685.0
# 4                  105939        109089           1854.0             1833.0
# ..                    ...           ...              ...                ...
# 446                158318        160892           1380.0             1528.0
# 447                158639        161031           1348.0             1416.0
# 448                158416        160721           1583.0             1534.0
# 449                158853        160994           1418.0             1492.0
# 450                159099        161262           1451.0             1334.0
#
#            GDP  GDP_incre_lastQuarter  personal_saving_rate  avg_house_prices  \
# 0     4507.894               0.012982                   8.7           86600.0
# 1          NaN               0.012982                   9.3           89700.0
# 2          NaN               0.012982                   9.9           88700.0
# 3     4545.340               0.014254                   9.7           92500.0
# 4          NaN               0.014254                   9.3           92100.0
# ..         ...                    ...                   ...               ...
# 446        NaN               0.015792                   5.2          438900.0
# 447  27063.012               0.015227                   5.2          417200.0
# 448        NaN               0.015227                   5.3          421200.0
# 449        NaN               0.015227                   4.9          416700.0
# 450        NaN               0.009259                   4.1          436600.0
#
#      mortgage
# 0     10.8860
# 1     10.7100
# 2     10.0800
# 3      9.9375
# 4     10.1440
# ..        ...
# 446    6.5440
# 447    6.3425
# 448    6.4250
# 449    6.7140
# 450    6.8400
#
# [451 rows x 18 columns]

# %% [markdown]
# ## $log Y$ : Transform the indicators into more linear tread
#
# Some indicators are influenced by inflation. One dollar in 1980s is different from one dollar today.

# %%
## process the variables to make it more logical
analyze_data = aligned_data[["date","capacity_util","real_interest_rate", "fed_fund_rate","stickyCPI","housing_started",
                             "housing_completed","personal_saving_rate","unemploy_rate","GDP_incre_lastQuarter", "mortgage"]].copy()

## log difference
analyze_data["log_GDP"] = np.log(aligned_data["GDP"].ffill())
analyze_data["log_CPI"] = np.log(aligned_data["CPI"])
analyze_data["log_PCE"] = np.log(aligned_data["PCE"])
analyze_data["log_avg_house_prices"] = np.log(aligned_data["avg_house_prices"])
analyze_data["employ_rate_nonagri"] = aligned_data["employ_level_nonagri"] / aligned_data["employ_level"]
analyze_data["log_national_home_price_index"] = np.log(aligned_data["national_home_price_index"])
analyze_data["delta_national_home_price_index"] = np.log(aligned_data["national_home_price_index"]).diff()
                       ##analyze_data.to_csv("../data/Analyze_data.csv", index = False)
analyze_data
# Out:
#           date  capacity_util  real_interest_rate  fed_fund_rate  stickyCPI  \
# 0   1986-01-01        79.5636            4.547185           8.14   0.487140
# 1   1986-02-01        78.9134            4.623880           7.86   0.363870
# 2   1986-03-01        78.2664            4.209182           7.48   0.488280
# 3   1986-04-01        78.2696            3.948305           6.99   0.448070
# 4   1986-05-01        78.3421            4.046590           6.85   0.262490
# ..         ...            ...                 ...            ...        ...
# 446 2023-03-01        79.5118            2.059636           4.65   0.383314
# 447 2023-04-01        79.7900            1.443914           4.83   0.382397
# 448 2023-05-01        79.4570            1.536904           5.06   0.336291
# 449 2023-06-01        78.9301            1.060631           5.08   0.241034
# 450 2023-07-01        79.6066            1.426047           5.12   0.256887
#
#      housing_started  housing_completed  personal_saving_rate  unemploy_rate  \
# 0             1972.0             1723.0                   8.7            6.7
# 1             1848.0             1753.0                   9.3            7.2
# 2             1876.0             1756.0                   9.9            7.2
# 3             1933.0             1685.0                   9.7            7.1
# 4             1854.0             1833.0                   9.3            7.2
# ..               ...                ...                   ...            ...
# 446           1380.0             1528.0                   5.2            3.5
# 447           1348.0             1416.0                   5.2            3.4
# 448           1583.0             1534.0                   5.3            3.7
# 449           1418.0             1492.0                   4.9            3.6
# 450           1451.0             1334.0                   4.1            3.5
#
#      GDP_incre_lastQuarter  mortgage    log_GDP   log_CPI   log_PCE  \
# 0                 0.012982   10.8860   8.413585  4.699571  7.947007
# 1                 0.012982   10.7100   8.413585  4.697749  7.944563
# 2                 0.012982   10.0800   8.413585  4.692265  7.945768
# 3                 0.014254    9.9375   8.421858  4.688592  7.949868
# 4                 0.014254   10.1440   8.421858  4.691348  7.957702
# ..                     ...       ...        ...       ...       ...
# 446               0.015792    6.5440  10.196665  5.709791  9.813705
# 447               0.015227    6.3425  10.205923  5.713462  9.818137
# 448               0.015227    6.4250  10.205923  5.714703  9.820530
# 449               0.015227    6.7140  10.205923  5.716505  9.824737
# 450               0.009259    6.8400  10.205923  5.718172  9.833242
#
#      log_avg_house_prices  employ_rate_nonagri  log_national_home_price_index  \
# 0               11.369055             0.969813                            NaN
# 1               11.404226             0.971580                            NaN
# 2               11.393015             0.970598                            NaN
# 3               11.434964             0.971061                            NaN
# 4               11.430630             0.971124                            NaN
# ..                    ...                  ...                            ...
# 446             12.992027             0.984002                       5.694802
# 447             12.941321             0.985146                       5.708644
# 448             12.950863             0.985658                       5.721691
# 449             12.940122             0.986701                       5.731125
# 450             12.986773             0.986587                       5.737082
#
#      delta_national_home_price_index
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ..                               ...
# 446                         0.013023
# 447                         0.013842
# 448                         0.013047
# 449                         0.009434
# 450                         0.005957
#
# [451 rows x 18 columns]

# %%
sns.lineplot(x = "date", y = "log_national_home_price_index", data = analyze_data)
plt.savefig("log_national_home_price_index.png")
plt.show()

# %%
sns.lineplot(x = "date", y = "delta_national_home_price_index", data = analyze_data)
plt.savefig("delta_log_national_home_price_index.png")
plt.show()

# %% [markdown]
# ## Descriptive Stats: If Stationary？

# %% [markdown]
# We can see from the graph that the indicators have significant trend. We expect that they are not stationary and need some adjustment later.

# %%
## autocorrelation 
variables = analyze_data.columns
fig, axs = plt.subplots(9, 2, sharey= True, figsize = (10,30))
for i in range(1,len(variables)):
    row = (i-1) // 2
    col = (i-1) % 2
    d = analyze_data[variables[i]].dropna()
    plot_acf(d, ax = axs[row,col], title = variables[i])
plt.show()

# %% [markdown]
# ### Findings:
#
# * All the marco indicators are not likely to be stationary without one-oder difference ,the autocorrelation coefficent decays linearly and slowly.
# * Those indicators with one-oder difference is stationary : change rate is stationary.
# * National home price index may show some seasonality, with 12 months as a period.

# %% [markdown]
# #### ADF test: Augmented Dickey-Fuller Unit Root Test

# %%
## adfuller test results
def adfuller_df(df):
    adftest = []
    variables = df.columns
    for var in variables[1:]:
        res = adfuller(df[var].dropna())
        if res[1] < 0.01:
            sig = "***"
        elif res[1] < 0.05:
            sig = "**"
        elif res[1] < 0.1:
            sig = "*"
        else:
            sig = "-"
        res_dict = adftest.append({"variable":var, "ADF stats": res[0], "p-value":res[1], "stationary":sig})
    return adftest 
    
adftest = adfuller_df(analyze_data)
adftest_result = pd.DataFrame(adftest).drop_duplicates() 
adftest_result
# Out:
#                            variable  ADF stats   p-value stationary
# 0                     capacity_util  -3.050236  0.030462         **
# 1                real_interest_rate  -2.024542  0.275917          -
# 2                     fed_fund_rate  -2.891258  0.046374         **
# 3                         stickyCPI  -3.282932  0.015659         **
# 4                   housing_started  -2.376407  0.148506          -
# 5                 housing_completed  -2.355189  0.154785          -
# 6              personal_saving_rate  -3.412584  0.010537         **
# 7                     unemploy_rate  -3.343796  0.013031         **
# 8             GDP_incre_lastQuarter  -4.299006  0.000446        ***
# 9                          mortgage  -1.769797  0.395556          -
# 10                          log_GDP  -1.227657  0.661587          -
# 11                          log_CPI  -0.941488  0.774003          -
# 12                          log_PCE  -1.245394  0.653770          -
# 13             log_avg_house_prices  -0.461879  0.899243          -
# 14              employ_rate_nonagri  -1.371908  0.595667          -
# 15    log_national_home_price_index   0.323645  0.978404          -
# 16  delta_national_home_price_index  -3.601551  0.005731        ***

# %%
### diff the non-stationary indicators
analyze_data["delta_real_interest_rate"] = analyze_data["real_interest_rate"].diff()
analyze_data["delta_housing_started"] = analyze_data["housing_started"].diff()
analyze_data["delta_housing_completed"] = analyze_data["housing_completed"].diff()
analyze_data["delta_logCPI"] = analyze_data["log_CPI"].diff()
analyze_data["delta_logPCE"] = analyze_data["log_PCE"].diff()
analyze_data["delta_employ_rate_nonagri"] = analyze_data["employ_rate_nonagri"].diff()
analyze_data["delta_mortgage"] = analyze_data["mortgage"].diff()
analyze_data["delta_avg_house_prices"] = analyze_data["log_avg_house_prices"].diff()

d = analyze_data.pop("delta_national_home_price_index")
analyze_data.insert(1,"delta_national_home_price_index",d)
d = analyze_data.pop("log_national_home_price_index")
analyze_data.insert(1,"log_national_home_price_index",d)

analyze_data.to_csv("../data/Analyze_data.csv", index = False)

# %% [markdown]
# ##  Correlation & Cointegration

# %%
## correlation matrix
corr_df = analyze_data.dropna().corr()
corr_df
# Out:
#                                  log_national_home_price_index  \
# log_national_home_price_index                         1.000000
# delta_national_home_price_index                       0.113164
# capacity_util                                        -0.515992
# real_interest_rate                                   -0.828522
# fed_fund_rate                                        -0.664258
# stickyCPI                                            -0.146925
# housing_started                                      -0.045737
# housing_completed                                    -0.110190
# personal_saving_rate                                 -0.167940
# unemploy_rate                                        -0.157073
# GDP_incre_lastQuarter                                -0.049027
# mortgage                                             -0.817675
# log_GDP                                               0.966125
# log_CPI                                               0.955809
# log_PCE                                               0.965764
# log_avg_house_prices                                  0.983035
# employ_rate_nonagri                                   0.893444
# delta_real_interest_rate                              0.027269
# delta_housing_started                                -0.004856
# delta_housing_completed                               0.008534
# delta_logCPI                                         -0.018938
# delta_logPCE                                         -0.037939
# delta_employ_rate_nonagri                            -0.008528
# delta_mortgage                                        0.086824
# delta_avg_house_prices                                0.002065
#
#                                  delta_national_home_price_index  \
# log_national_home_price_index                           0.113164
# delta_national_home_price_index                         1.000000
# capacity_util                                           0.030150
# real_interest_rate                                     -0.078956
# fed_fund_rate                                          -0.075364
# stickyCPI                                              -0.006100
# housing_started                                         0.444235
# housing_completed                                       0.292396
# personal_saving_rate                                    0.122008
# unemploy_rate                                          -0.170822
# GDP_incre_lastQuarter                                   0.136008
# mortgage                                               -0.111516
# log_GDP                                                 0.085312
# log_CPI                                                 0.064609
# log_PCE                                                 0.081726
# log_avg_house_prices                                    0.126878
# employ_rate_nonagri                                     0.046125
# delta_real_interest_rate                                0.090260
# delta_housing_started                                   0.042786
# delta_housing_completed                                 0.077311
# delta_logCPI                                            0.183697
# delta_logPCE                                            0.090397
# delta_employ_rate_nonagri                               0.067389
# delta_mortgage                                          0.176765
# delta_avg_house_prices                                  0.035458
#
#                                  capacity_util  real_interest_rate  \
# log_national_home_price_index        -0.515992           -0.828522
# delta_national_home_price_index       0.030150           -0.078956
# capacity_util                         1.000000            0.697376
# real_interest_rate                    0.697376            1.000000
# fed_fund_rate                         0.762462            0.903136
# stickyCPI                             0.458059            0.429913
# housing_started                       0.429616            0.305061
# housing_completed                     0.423312            0.449734
# personal_saving_rate                 -0.132545            0.021667
# unemploy_rate                        -0.543284           -0.186932
# GDP_incre_lastQuarter                 0.361106            0.163693
# mortgage                              0.657008            0.983193
# log_GDP                              -0.559556           -0.905203
# log_CPI                              -0.567612           -0.909624
# log_PCE                              -0.568352           -0.908508
# log_avg_house_prices                 -0.500666           -0.858443
# employ_rate_nonagri                  -0.660746           -0.844357
# delta_real_interest_rate              0.019071            0.064697
# delta_housing_started                -0.027702           -0.059983
# delta_housing_completed              -0.004712           -0.033317
# delta_logCPI                          0.219917            0.147292
# delta_logPCE                          0.114869            0.063896
# delta_employ_rate_nonagri             0.036098            0.023760
# delta_mortgage                        0.066481            0.009859
# delta_avg_house_prices                0.000642           -0.020826
#
#                                  fed_fund_rate  stickyCPI  housing_started  \
# log_national_home_price_index        -0.664258  -0.146925        -0.045737
# delta_national_home_price_index      -0.075364  -0.006100         0.444235
# capacity_util                         0.762462   0.458059         0.429616
# real_interest_rate                    0.903136   0.429913         0.305061
# fed_fund_rate                         1.000000   0.481802         0.351115
# stickyCPI                             0.481802   1.000000         0.247562
# housing_started                       0.351115   0.247562         1.000000
# housing_completed                     0.505298   0.279088         0.916221
# personal_saving_rate                 -0.007148  -0.017279        -0.183890
# unemploy_rate                        -0.371072  -0.365521        -0.604129
# GDP_incre_lastQuarter                 0.179798   0.151293         0.272738
# mortgage                              0.899704   0.465022         0.263177
# log_GDP                              -0.754762  -0.264791        -0.181543
# log_CPI                              -0.768654  -0.268644        -0.220423
# log_PCE                              -0.761626  -0.271186        -0.184721
# log_avg_house_prices                 -0.698377  -0.165532        -0.102705
# employ_rate_nonagri                  -0.725929  -0.315727        -0.137223
# delta_real_interest_rate             -0.033256   0.043706         0.084558
# delta_housing_started                -0.063585  -0.005559         0.126749
# delta_housing_completed              -0.060955   0.039686         0.075381
# delta_logCPI                          0.188694   0.426868         0.193816
# delta_logPCE                          0.065853   0.158440         0.142185
# delta_employ_rate_nonagri             0.030669   0.047581         0.048003
# delta_mortgage                       -0.023415   0.123657         0.136641
# delta_avg_house_prices               -0.022424  -0.037338         0.032538
#
#                                  housing_completed  personal_saving_rate  \
# log_national_home_price_index            -0.110190             -0.167940
# delta_national_home_price_index           0.292396              0.122008
# capacity_util                             0.423312             -0.132545
# real_interest_rate                        0.449734              0.021667
# fed_fund_rate                             0.505298             -0.007148
# stickyCPI                                 0.279088             -0.017279
# housing_started                           0.916221             -0.183890
# housing_completed                         1.000000             -0.217166
# personal_saving_rate                     -0.217166              1.000000
# unemploy_rate                            -0.581384              0.438981
# GDP_incre_lastQuarter                     0.201079             -0.128535
# mortgage                                  0.420496              0.018436
# log_GDP                                  -0.279896             -0.143423
# log_CPI                                  -0.320656             -0.133578
# log_PCE                                  -0.282000             -0.154845
# log_avg_house_prices                     -0.200833             -0.134471
# employ_rate_nonagri                      -0.174711             -0.294131
# delta_real_interest_rate                  0.049260             -0.020818
# delta_housing_started                    -0.024840              0.047552
# delta_housing_completed                   0.105893              0.035550
# delta_logCPI                              0.140759             -0.050114
# delta_logPCE                              0.093132             -0.053359
# delta_employ_rate_nonagri                 0.042320             -0.001553
# delta_mortgage                            0.084389             -0.105212
# delta_avg_house_prices                    0.014591             -0.004300
#
#                                  unemploy_rate  ...  log_avg_house_prices  \
# log_national_home_price_index        -0.157073  ...              0.983035
# delta_national_home_price_index      -0.170822  ...              0.126878
# capacity_util                        -0.543284  ...             -0.500666
# real_interest_rate                   -0.186932  ...             -0.858443
# fed_fund_rate                        -0.371072  ...             -0.698377
# stickyCPI                            -0.365521  ...             -0.165532
# housing_started                      -0.604129  ...             -0.102705
# housing_completed                    -0.581384  ...             -0.200833
# personal_saving_rate                  0.438981  ...             -0.134471
# unemploy_rate                         1.000000  ...             -0.157241
# GDP_incre_lastQuarter                -0.297226  ...             -0.041755
# mortgage                             -0.143648  ...             -0.855135
# log_GDP                              -0.088998  ...              0.982831
# log_CPI                              -0.051786  ...              0.975458
# log_PCE                              -0.080953  ...              0.981017
# log_avg_house_prices                 -0.157241  ...              1.000000
# employ_rate_nonagri                   0.003058  ...              0.866002
# delta_real_interest_rate             -0.023200  ...              0.039116
# delta_housing_started                 0.036555  ...              0.006673
# delta_housing_completed              -0.000648  ...              0.020164
# delta_logCPI                         -0.139306  ...             -0.035884
# delta_logPCE                         -0.052296  ...             -0.035557
# delta_employ_rate_nonagri            -0.026441  ...             -0.012134
# delta_mortgage                       -0.105052  ...              0.093215
# delta_avg_house_prices                0.004082  ...              0.057843
#
#                                  employ_rate_nonagri  \
# log_national_home_price_index               0.893444
# delta_national_home_price_index             0.046125
# capacity_util                              -0.660746
# real_interest_rate                         -0.844357
# fed_fund_rate                              -0.725929
# stickyCPI                                  -0.315727
# housing_started                            -0.137223
# housing_completed                          -0.174711
# personal_saving_rate                       -0.294131
# unemploy_rate                               0.003058
# GDP_incre_lastQuarter                      -0.152402
# mortgage                                   -0.813431
# log_GDP                                     0.889218
# log_CPI                                     0.878893
# log_PCE                                     0.896528
# log_avg_house_prices                        0.866002
# employ_rate_nonagri                         1.000000
# delta_real_interest_rate                   -0.002064
# delta_housing_started                       0.004307
# delta_housing_completed                     0.010872
# delta_logCPI                               -0.102256
# delta_logPCE                               -0.063408
# delta_employ_rate_nonagri                   0.059245
# delta_mortgage                              0.022450
# delta_avg_house_prices                      0.001908
#
#                                  delta_real_interest_rate  \
# log_national_home_price_index                    0.027269
# delta_national_home_price_index                  0.090260
# capacity_util                                    0.019071
# real_interest_rate                               0.064697
# fed_fund_rate                                   -0.033256
# stickyCPI                                        0.043706
# housing_started                                  0.084558
# housing_completed                                0.049260
# personal_saving_rate                            -0.020818
# unemploy_rate                                   -0.023200
# GDP_incre_lastQuarter                            0.020721
# mortgage                                         0.033090
# log_GDP                                          0.017894
# log_CPI                                          0.015571
# log_PCE                                          0.017563
# log_avg_house_prices                             0.039116
# employ_rate_nonagri                             -0.002064
# delta_real_interest_rate                         1.000000
# delta_housing_started                           -0.002773
# delta_housing_completed                          0.104258
# delta_logCPI                                     0.056389
# delta_logPCE                                     0.057994
# delta_employ_rate_nonagri                       -0.004427
# delta_mortgage                                   0.670253
# delta_avg_house_prices                           0.039372
#
#                                  delta_housing_started  \
# log_national_home_price_index                -0.004856
# delta_national_home_price_index               0.042786
# capacity_util                                -0.027702
# real_interest_rate                           -0.059983
# fed_fund_rate                                -0.063585
# stickyCPI                                    -0.005559
# housing_started                               0.126749
# housing_completed                            -0.024840
# personal_saving_rate                          0.047552
# unemploy_rate                                 0.036555
# GDP_incre_lastQuarter                        -0.021180
# mortgage                                     -0.069057
# log_GDP                                       0.016489
# log_CPI                                       0.018751
# log_PCE                                       0.019410
# log_avg_house_prices                          0.006673
# employ_rate_nonagri                           0.004307
# delta_real_interest_rate                     -0.002773
# delta_housing_started                         1.000000
# delta_housing_completed                       0.246395
# delta_logCPI                                  0.080604
# delta_logPCE                                  0.272336
# delta_employ_rate_nonagri                     0.077530
# delta_mortgage                               -0.066760
# delta_avg_house_prices                       -0.030968
#
#                                  delta_housing_completed  delta_logCPI  \
# log_national_home_price_index                   0.008534     -0.018938
# delta_national_home_price_index                 0.077311      0.183697
# capacity_util                                  -0.004712      0.219917
# real_interest_rate                             -0.033317      0.147292
# fed_fund_rate                                  -0.060955      0.188694
# stickyCPI                                       0.039686      0.426868
# housing_started                                 0.075381      0.193816
# housing_completed                               0.105893      0.140759
# personal_saving_rate                            0.035550     -0.050114
# unemploy_rate                                  -0.000648     -0.139306
# GDP_incre_lastQuarter                          -0.039424      0.106255
# mortgage                                       -0.048639      0.156495
# log_GDP                                         0.026123     -0.087862
# log_CPI                                         0.027201     -0.092035
# log_PCE                                         0.025673     -0.086637
# log_avg_house_prices                            0.020164     -0.035884
# employ_rate_nonagri                             0.010872     -0.102256
# delta_real_interest_rate                        0.104258      0.056389
# delta_housing_started                           0.246395      0.080604
# delta_housing_completed                         1.000000     -0.020913
# delta_logCPI                                   -0.020913      1.000000
# delta_logPCE                                    0.046238      0.317897
# delta_employ_rate_nonagri                       0.075451      0.092387
# delta_mortgage                                  0.063865      0.185636
# delta_avg_house_prices                         -0.025385      0.016774
#
#                                  delta_logPCE  delta_employ_rate_nonagri  \
# log_national_home_price_index       -0.037939                  -0.008528
# delta_national_home_price_index      0.090397                   0.067389
# capacity_util                        0.114869                   0.036098
# real_interest_rate                   0.063896                   0.023760
# fed_fund_rate                        0.065853                   0.030669
# stickyCPI                            0.158440                   0.047581
# housing_started                      0.142185                   0.048003
# housing_completed                    0.093132                   0.042320
# personal_saving_rate                -0.053359                  -0.001553
# unemploy_rate                       -0.052296                  -0.026441
# GDP_incre_lastQuarter               -0.000866                  -0.067041
# mortgage                             0.053780                   0.025276
# log_GDP                             -0.057907                  -0.008740
# log_CPI                             -0.061458                  -0.010136
# log_PCE                             -0.048945                  -0.008672
# log_avg_house_prices                -0.035557                  -0.012134
# employ_rate_nonagri                 -0.063408                   0.059245
# delta_real_interest_rate             0.057994                  -0.004427
# delta_housing_started                0.272336                   0.077530
# delta_housing_completed              0.046238                   0.075451
# delta_logCPI                         0.317897                   0.092387
# delta_logPCE                         1.000000                   0.078460
# delta_employ_rate_nonagri            0.078460                   1.000000
# delta_mortgage                       0.058860                   0.018055
# delta_avg_house_prices               0.084370                  -0.004239
#
#                                  delta_mortgage  delta_avg_house_prices
# log_national_home_price_index          0.086824                0.002065
# delta_national_home_price_index        0.176765                0.035458
# capacity_util                          0.066481                0.000642
# real_interest_rate                     0.009859               -0.020826
# fed_fund_rate                         -0.023415               -0.022424
# stickyCPI                              0.123657               -0.037338
# housing_started                        0.136641                0.032538
# housing_completed                      0.084389                0.014591
# personal_saving_rate                  -0.105212               -0.004300
# unemploy_rate                         -0.105052                0.004082
# GDP_incre_lastQuarter                  0.054483                0.037290
# mortgage                               0.027930               -0.019631
# log_GDP                                0.063917                0.001596
# log_CPI                                0.061168               -0.000071
# log_PCE                                0.063528                0.002557
# log_avg_house_prices                   0.093215                0.057843
# employ_rate_nonagri                    0.022450                0.001908
# delta_real_interest_rate               0.670253                0.039372
# delta_housing_started                 -0.066760               -0.030968
# delta_housing_completed                0.063865               -0.025385
# delta_logCPI                           0.185636                0.016774
# delta_logPCE                           0.058860                0.084370
# delta_employ_rate_nonagri              0.018055               -0.004239
# delta_mortgage                         1.000000                0.038485
# delta_avg_house_prices                 0.038485                1.000000
#
# [25 rows x 25 columns]

# %%
plt.figure(figsize = (18,14))
sns.heatmap(corr_df,cmap=palettable.cmocean.diverging.Curl_10.mpl_colors)
plt.savefig("correlation matrix.png")

# %%
corr_df.loc["log_national_home_price_index",:].T
# Out:
# log_national_home_price_index      1.000000
# delta_national_home_price_index    0.113164
# capacity_util                     -0.515992
# real_interest_rate                -0.828522
# fed_fund_rate                     -0.664258
# stickyCPI                         -0.146925
# housing_started                   -0.045737
# housing_completed                 -0.110190
# personal_saving_rate              -0.167940
# unemploy_rate                     -0.157073
# GDP_incre_lastQuarter             -0.049027
# mortgage                          -0.817675
# log_GDP                            0.966125
# log_CPI                            0.955809
# log_PCE                            0.965764
# log_avg_house_prices               0.983035
# employ_rate_nonagri                0.893444
# delta_real_interest_rate           0.027269
# delta_housing_started             -0.004856
# delta_housing_completed            0.008534
# delta_logCPI                      -0.018938
# delta_logPCE                      -0.037939
# delta_employ_rate_nonagri         -0.008528
# delta_mortgage                     0.086824
# delta_avg_house_prices             0.002065
# Name: log_national_home_price_index, dtype: float64

# %%
np.sqrt(1 / 400)* 1.96 ## an estimation of significance
# Out:
# 0.098

# %%
## Lagged Cross Correlation with national_home_price_index
## To find a propriate lag periods -- select some correlated variables from above matrix
variables = ["personal_saving_rate","unemploy_rate","delta_housing_completed",
            "GDP_incre_lastQuarter","delta_logCPI","mortgage", "delta_mortgage","log_avg_house_prices"]
fig, axs = plt.subplots(4, 2, sharey= True, figsize = (10,14))
for i in range(len(variables)):
    row = (i) // 2
    col = (i) % 2
    var = variables[i]
    ax = axs[row, col]
    d = analyze_data[["delta_national_home_price_index",var]].dropna()
    y = d["delta_national_home_price_index"] - d["delta_national_home_price_index"].mean()
    x = d[var] - d[var].mean()
    ax.xcorr(x, y, usevlines=True, maxlags=24, normed=True, lw=2)
    ax.grid(True)
    ax.set_title("Lagged Corr with " + var)
plt.savefig("lagged corr.png")
plt.show()

# %% [markdown]
# #### Cointegration Test with the non-diff series

# %%
### cointegration test -- whether there is false correlation
coint_test_data = analyze_data.copy().dropna().reset_index(drop = True).reset_index()
var_lists = [ 'capacity_util', 'real_interest_rate', 'fed_fund_rate','stickyCPI', 'housing_started', 'housing_completed',
       'personal_saving_rate', 'unemploy_rate', 'GDP_incre_lastQuarter','log_GDP', 'log_CPI', 'log_PCE', 'employ_rate_nonagri',
            "mortgage","log_avg_house_prices"]

def cointegration_test(var, coint_test_data, verbose = False):
    ## detrend
    ind = coint_test_data[["index"]]
    x_ind = sm.add_constant(ind)
    x_var = coint_test_data[var]
    y_var = coint_test_data["log_national_home_price_index"]
    lm_y = sm.OLS(y_var, x_ind).fit() 
    Y = lm_y.resid
    lm_x = sm.OLS(x_var ,x_ind).fit()
    X = sm.add_constant(lm_x.resid)
    
    lm = sm.OLS(Y,X).fit() ## regression with y = a + cX
    if verbose:
        print(lm.summary())
    resid = lm.resid       ## get the residuals
    p = adfuller(resid)[1] ## test whether the residuals is stationary
    sig = "**" if p < 0.05 else ("*" if p < 0.1 else "--")
    return {"variable":var, "p-value":p, "cointegrate":sig}

result = [cointegration_test(var, coint_test_data) for var in var_lists]
coint_result = pd.DataFrame(result)
coint_result
# Out:
#                  variable   p-value cointegrate
# 0           capacity_util  0.112000          --
# 1      real_interest_rate  0.243500          --
# 2           fed_fund_rate  0.238311          --
# 3               stickyCPI  0.218340          --
# 4         housing_started  0.012409          **
# 5       housing_completed  0.158691          --
# 6    personal_saving_rate  0.078044           *
# 7           unemploy_rate  0.185408          --
# 8   GDP_incre_lastQuarter  0.025197          **
# 9                 log_GDP  0.013819          **
# 10                log_CPI  0.202825          --
# 11                log_PCE  0.013106          **
# 12    employ_rate_nonagri  0.017566          **
# 13               mortgage  0.409797          --
# 14   log_avg_house_prices  0.294132          --

# %% [markdown]
# #### Assumption of the regression:
# * Variables X are strictly exogenous.
# * We can get the X_t at the time we want to predict Y_t because the home price index is usually released later than the other indicators.

# %% [markdown]
# ## PCA： find economical fundamental factorsc from these indicators

# %%
### copy the data
pca_data = aligned_data.copy()
pca_data["log_national_home_price_index"] = np.log(pca_data["national_home_price_index"])
pca_data["delta_national_home_price_index"] = np.log(pca_data["national_home_price_index"]).diff()
var_lists = ["real_interest_rate","capacity_util","CPI","stickyCPI","PCE", "fed_fund_rate","unemploy_rate",
    "employ_level_nonagri", "employ_level", "housing_started","housing_completed","GDP","personal_saving_rate",
    "avg_house_prices","mortgage"]
vars_data = pca_data[var_lists].ffill()

# %%
vars_data = (vars_data - vars_data.mean()) / vars_data.std() ## normalize
pca_model= PCA(n_components=10)
pca_model.fit(vars_data)
## plot the variance explained
plt.plot(range(1,len(pca_model.explained_variance_ratio_)+1),pca_model.explained_variance_ratio_)
plt.title("Variance Ratio Explained by the PCA components - 2 or 3 is enough")
plt.savefig("PCA variance explained.png")
plt.show()

# %%
pca = PCA(n_components=3)
principalComponents = pca.fit_transform(vars_data)
principalDf = pd.DataFrame(data = principalComponents,columns = ['PC1', 'PC2',"PC3"])

# %%
### LOADINGS of PCA 
pd.DataFrame(pca.components_,columns = var_lists)
# Out:
#    real_interest_rate  capacity_util       CPI  stickyCPI       PCE  \
# 0            0.323736       0.214402 -0.327952   0.129018 -0.321219
# 1           -0.065561      -0.277615 -0.094571  -0.243219 -0.125273
# 2            0.100311       0.204029  0.121746   0.655462  0.169525
#
#    fed_fund_rate  unemploy_rate  employ_level_nonagri  employ_level  \
# 0       0.290916      -0.011108             -0.315659     -0.314783
# 1      -0.170692       0.527891             -0.182015     -0.186516
# 2       0.192053      -0.027844             -0.038959     -0.032438
#
#    housing_started  housing_completed       GDP  personal_saving_rate  \
# 0         0.119715           0.155377 -0.320372              0.038020
# 1        -0.413265          -0.399906 -0.127782              0.276314
# 2        -0.305401          -0.301540  0.174812              0.397935
#
#    avg_house_prices  mortgage
# 0         -0.303960  0.321579
# 1         -0.182984 -0.047356
# 2          0.209671  0.133490

# %% [markdown]
# * PCA1: focus on interest rate and growth
# * PCA2: focus on unemployment, negative side of the economy
# * PCA3: inflation

# %%
lowdim_data = pca_data[["date","delta_national_home_price_index","log_national_home_price_index"]]
lowdim_data = pd.concat([lowdim_data, principalDf], axis = 1)
lowdim_data["delta_PC1"] = lowdim_data["PC1"].diff()
lowdim_data["delta_PC2"] = lowdim_data["PC2"].diff()
lowdim_data["delta_PC3"] = lowdim_data["PC3"].diff()
lowdim_data
# Out:
#           date  delta_national_home_price_index  \
# 0   1986-01-01                              NaN
# 1   1986-02-01                              NaN
# 2   1986-03-01                              NaN
# 3   1986-04-01                              NaN
# 4   1986-05-01                              NaN
# ..         ...                              ...
# 446 2023-03-01                         0.013023
# 447 2023-04-01                         0.013842
# 448 2023-05-01                         0.013047
# 449 2023-06-01                         0.009434
# 450 2023-07-01                         0.005957
#
#      log_national_home_price_index       PC1       PC2       PC3  delta_PC1  \
# 0                              NaN  5.581427 -0.169375  0.789936        NaN
# 1                              NaN  5.350647  0.478354  0.178671  -0.230779
# 2                              NaN  5.240088  0.337575  0.815349  -0.110559
# 3                              NaN  5.028772  0.424110  0.520820  -0.211316
# 4                              NaN  4.885682  0.721885 -0.648562  -0.143090
# ..                             ...       ...       ...       ...        ...
# 446                       5.694802 -3.585965 -3.406567  2.015877  -0.073441
# 447                       5.708644 -3.742167 -3.248109  2.067831  -0.156202
# 448                       5.721691 -3.638782 -3.430520  1.547303   0.103385
# 449                       5.731125 -3.925449 -3.022124  1.063849  -0.286667
# 450                       5.737082 -3.925723 -3.147851  1.278638  -0.000274
#
#      delta_PC2  delta_PC3
# 0          NaN        NaN
# 1     0.647729  -0.611265
# 2    -0.140779   0.636678
# 3     0.086534  -0.294530
# 4     0.297775  -1.169381
# ..         ...        ...
# 446   0.424054  -0.727907
# 447   0.158457   0.051954
# 448  -0.182411  -0.520528
# 449   0.408396  -0.483454
# 450  -0.125727   0.214789
#
# [451 rows x 9 columns]

# %%
## stationary test
adftest = adfuller_df(lowdim_data)
adftest_result = pd.DataFrame(adftest).drop_duplicates() 
adftest_result
# Out:
#                           variable  ADF stats       p-value stationary
# 0  delta_national_home_price_index  -3.601551  5.731440e-03        ***
# 1    log_national_home_price_index   0.323645  9.784037e-01          -
# 2                              PC1  -1.351303  6.053869e-01          -
# 3                              PC2  -2.019917  2.779090e-01          -
# 4                              PC3  -1.515841  5.256612e-01          -
# 5                        delta_PC1 -26.523780  0.000000e+00        ***
# 6                        delta_PC2 -14.782274  2.235981e-27        ***
# 7                        delta_PC3 -14.412017  8.174867e-27        ***

# %%
## correlation matrix
corr_df = lowdim_data.dropna().corr()
corr_df
# Out:
#                                  delta_national_home_price_index  \
# delta_national_home_price_index                         1.000000
# log_national_home_price_index                           0.113164
# PC1                                                    -0.055693
# PC2                                                    -0.243699
# PC3                                                    -0.125347
# delta_PC1                                               0.115032
# delta_PC2                                              -0.090556
# delta_PC3                                              -0.000292
#
#                                  log_national_home_price_index       PC1  \
# delta_national_home_price_index                       0.113164 -0.055693
# log_national_home_price_index                         1.000000 -0.918620
# PC1                                                  -0.918620  1.000000
# PC2                                                  -0.296362 -0.013566
# PC3                                                   0.038710 -0.002002
# delta_PC1                                             0.020672  0.004488
# delta_PC2                                            -0.014774  0.010751
# delta_PC3                                             0.016226  0.011098
#
#                                       PC2       PC3  delta_PC1  delta_PC2  \
# delta_national_home_price_index -0.243699 -0.125347   0.115032  -0.090556
# log_national_home_price_index   -0.296362  0.038710   0.020672  -0.014774
# PC1                             -0.013566 -0.002002   0.004488   0.010751
# PC2                              1.000000  0.000897  -0.044722   0.152587
# PC3                              0.000897  1.000000   0.131688  -0.061696
# delta_PC1                       -0.044722  0.131688   1.000000  -0.272012
# delta_PC2                        0.152587 -0.061696  -0.272012   1.000000
# delta_PC3                       -0.028440  0.239516   0.632627  -0.195073
#
#                                  delta_PC3
# delta_national_home_price_index  -0.000292
# log_national_home_price_index     0.016226
# PC1                               0.011098
# PC2                              -0.028440
# PC3                               0.239516
# delta_PC1                         0.632627
# delta_PC2                        -0.195073
# delta_PC3                         1.000000

# %%
sns.heatmap(corr_df,cmap=palettable.cmocean.diverging.Curl_10.mpl_colors)
# Out:
# <AxesSubplot:>

# %%
corr_df.loc[:,"delta_national_home_price_index"]
# Out:
# delta_national_home_price_index    1.000000
# log_national_home_price_index      0.113164
# PC1                               -0.055693
# PC2                               -0.243699
# PC3                               -0.125347
# delta_PC1                          0.115032
# delta_PC2                         -0.090556
# delta_PC3                         -0.000292
# Name: delta_national_home_price_index, dtype: float64

# %%
## Lagged Cross Correlation with national_home_price_index
variables = ["delta_PC1", "delta_PC2", "delta_PC3"]
fig, axs = plt.subplots(2, 2, sharey= True, figsize = (10,9))
for i in range(len(variables)):
    row = (i) // 2
    col = (i) % 2
    var = variables[i]
    ax = axs[row, col]
    d = lowdim_data[["delta_national_home_price_index",var]].dropna()
    y = d["delta_national_home_price_index"] - d["delta_national_home_price_index"].mean()
    x = d[var] - d[var].mean()
    ax.xcorr(x, y, usevlines=True, maxlags=24, normed=True, lw=2)
    ax.grid(True)
    ax.set_title("Lagged Corr (delta_home_price_index)\n with " + var)
plt.savefig("lag corr PCA.png")
plt.show()

# %%
## Lagged Cross Correlation with log_national_home_price_index
variables = ["PC1", "PC2",  "PC3"]
fig, axs = plt.subplots(2, 2, sharey= True, figsize = (10,7))
for i in range(len(variables)):
    row = (i) // 2
    col = (i) % 2
    var = variables[i]
    ax = axs[row, col]
    d = lowdim_data[["log_national_home_price_index",var]].dropna()
    y = d["log_national_home_price_index"] - d["log_national_home_price_index"].mean()
    x = d[var] - d[var].mean()
    ax.xcorr(x, y, usevlines=True, maxlags=24, normed=True, lw=2)
    ax.grid(True)
    ax.set_title("Lagged Corr with " + var)
plt.show()

# %%
## conintegration
### cointegration test -- whether there is false correlation
coint_test_data = lowdim_data.copy().dropna().reset_index(drop = True).reset_index()
var_lists = [ "PC1","PC2","PC3"]

def cointegration_test(var, coint_test_data, verbose = False):
    ## detrend
    ind = coint_test_data[["index"]]
    x_ind = sm.add_constant(ind)
    x_var = coint_test_data[var]
    y_var = coint_test_data["log_national_home_price_index"]
    lm_y = sm.OLS(y_var, x_ind).fit() 
    Y = lm_y.resid
    lm_x = sm.OLS(x_var ,x_ind).fit()
    X = sm.add_constant(lm_x.resid)
    
    lm = sm.OLS(Y,X).fit() ## regression with y = a + cX
    if verbose:
        print(lm.summary())
    resid = lm.resid       ## get the residuals
    p = adfuller(resid)[1] ## test whether the residuals is stationary
    sig = "**" if p < 0.05 else ("*" if p < 0.1 else "--")
    return {"variable":var, "p-value":p, "cointegrate":sig}

result = [cointegration_test(var, coint_test_data) for var in var_lists]
coint_result = pd.DataFrame(result)
coint_result
# Out:
#   variable   p-value cointegrate
# 0      PC1  0.297086          --
# 1      PC2  0.205280          --
# 2      PC3  0.079793           *

# %%
lowdim_data = lowdim_data.drop(["delta_national_home_price_index","log_national_home_price_index"], axis = 1)
lowdim_data.to_csv("../data/PCA_data.csv", index = False)
